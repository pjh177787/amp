# %% [markdown]
# # Pattern Recognition
# ## Part 1: Naive Bayes Classifiers on Digit Classification
# ### Part 1.1 Single Pixels as Features

# %%
from Bayesian_Model import *
np.set_printoptions(precision=4)

bayes = Bayesian_Model()
bayes.test()
# Out:
# For each digit, show the test examples from that class that have the highest and lowest posterior probabilities according to your classifier.
# [[-29640.901477832515, 6798], [-39697.897372742198, 11748], [-38402.899014778326, 9339], [-36491.896962233172, 726], [-42511.901067323481, 10593], [-40162.902709359609, 990], [-33578.901888341541, 11550], [-34609.897372742198, 7656], [-41254.905172413797, 3069], [-44949.896962233172, 3003]]
#
#
# [[-89897.897372742198, 8943], [-95448.899014778319, 8448], [-98432.901067323488, 10263], [-99452.901067323488, 13926], [-101268.89901477832, 8547], [-90373.897372742198, 4488], [-98009.897372742198, 14586], [-99435.901067323488, 6930], [-84880.901067323488, 14058], [-95266.901067323488, 14223]]
# Classification Rate For Each Digit:
# 0 1.0
# 1 0.9333333333333333
# 2 0.8536585365853658
# 3 1.0
# 4 0.7796610169491526
# 5 0.9827586206896551
# 6 0.9767441860465116
# 7 0.9787234042553191
# 8 0.975
# 9 0.47619047619047616
# Confusion Matrix:
# ...
