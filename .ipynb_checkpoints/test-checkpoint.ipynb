# %%
from search_1_2 import *
from itertools import combinations, permutations
from copy import deepcopy
import numpy as np
import time
    
    
def build_mst_3(goal_arr, dist_dict, start):
    min_mst = 9999
    min_goal = ()
    curr_node = start
    for goal in goal_arr:
        mst_goals = deepcopy(goal_arr)
        mst_goals.remove(goal)
        goal_length = len(mst_goals)
        cost = dist_dict[curr_node, goal]
        heu = cost
        if goal_length == 0:
            print('ja')
            min_goal = goal
        else:
            for goal_sec in mst_goals:
                mst_goals_sec = deepcopy(mst_goals)
                mst_goals_sec.remove(goal_sec)
                goal_length_sec = len(mst_goals_sec)
                cost = dist_dict[goal, goal_sec]
                heu_sec = heu + cost
                for goal_third in mst_goals_sec:
                    mst_goals_third = deepcopy(goal_arr)
                    mst_goals_third.remove(goal_third)
                    goal_length_third = len(mst_goals_third)
                    cost = dist_dict[goal_sec, goal_third]
#                     heu_third = heu_sec + cost
                
                    t = Tree(goal_length_third)
                    for i in range(goal_length_third - 1):
                        for j in range(i + 1, goal_length_third):
                            goal_i = mst_goals_third[i]
                            goal_j = mst_goals_third[j]
                            dist = dist_dict[(goal_i, goal_j)]
                            t.addEdge(i, j, dist)
                    mst_third = t.KruskalMST()
                    mst_path_len = 0
                    for edge in mst_third:
                        mst_path_len += edge[2]
                                       
                    heu_third = heu + cost + mst_path_len*goal_length_third/10
    #                 print((goal_sec, heu_sec))
                    if heu_third < min_mst :
                        min_mst = heu_third
                        min_goal = goal
    return min_mst, min_goal

def build_mst_2(goal_arr, dist_dict, start):
    min_mst = 9999
    min_goal = ()
    curr_node = start
    for goal in goal_arr:
#         print(goal)
        mst_goals = deepcopy(goal_arr)
#         mst_goals.remove(curr_node)
        mst_goals.remove(goal)
#         print(mst_goals)
        goal_length = len(mst_goals)
        t = Tree(goal_length)
        for i in range(goal_length - 1):
            for j in range(i + 1, goal_length):
                goal_i = mst_goals[i]
                goal_j = mst_goals[j]
                dist = dist_dict[(goal_i, goal_j)]
                t.addEdge(i, j, dist)
        mst = t.KruskalMST()
        mst_path_len = 0
        for edge in mst:
            mst_path_len += edge[2]
        cost = dist_dict[curr_node, goal]
        heu = cost + mst_path_len
        if goal_length == 0:
            print('ja')
            min_goal = goal
        else:
# #             print(min_goal)
#             for goal_sec in mst_goals:
#                 mst_goals_sec = deepcopy(mst_goals)
#                 mst_goals_sec.remove(goal_sec)
#                 goal_length_sec = len(mst_goals_sec)
#                 t = Tree(goal_length_sec)
#                 for i in range(goal_length_sec - 1):
#                     for j in range(i + 1, goal_length_sec):
#                         goal_i = mst_goals_sec[i]
#                         goal_j = mst_goals_sec[j]
#                         dist = dist_dict[(goal_i, goal_j)]
#                         t.addEdge(i, j, dist)
#                 mst_sec = t.KruskalMST()
#                 mst_path_len = 0
#                 for edge in mst_sec:
#                     mst_path_len += edge[2]
#                 cost = dist_dict[goal, goal_sec]
#                 heu_sec = heu + (cost + mst_path_len*goal_length_sec/10)*goal_length_sec/10
                print((goal, heu))
                if heu < min_mst :
                    min_mst = heu
                    min_goal = goal
    return min_mst, min_goal
    
fname = 'src/tinySearch.txt'
# sname_dfs = fname[:-4] + '_sol_dfs' + fname[-4:]
sname_bfs_4 = fname[:4] + 'p1_2_sol/' + fname[4:-4] + '_sol_bfs_4' + fname[-4:]
sname_bfs_5 = fname[:4] + 'p1_2_sol/' + fname[4:-4] + '_sol_bfs_5' + fname[-4:]

# %%
maze_map, start, goal_dict, index_dict = parse_file(fname)

total_path = ''
total_expanded = 0


# print(goal_dict)
# print(index_dict)
timer_s = time.clock()

dist_dict = {}
for goal_i, goal_j in combinations(index_dict.keys(), r = 2):
    path, expanded = find_path_astar(maze_map, goal_i, goal_j)
    total_expanded += expanded
    dist = len(path)
    dist_dict[(goal_i, goal_j)] = dist
    dist_dict[(goal_j, goal_i)] = dist

goal_arr = list(index_dict.keys())
# print(goal_arr)
length_orig = len(goal_arr)
curr_node = start
next_node = curr_node

goal_arr.remove(curr_node)

while goal_arr:
    length = len(goal_arr)
    
    if length == 0:
        print('DONE')
        break
    
    min_mst = 9999
    min_goal = ()
    _, next_node = build_mst_2(goal_arr, dist_dict, start)
    
    print(curr_node, '--->>', next_node)
    path, expanded = find_path_astar(maze_map, curr_node, next_node)
    
    total_path += path
    curr_node = next_node
    goal_arr.remove(next_node)
    curr_index = index_dict[curr_node]

timer_t = time.clock()
print('bfs takes', timer_t - timer_s, 
      'seconds, costs', len(total_path), 
      'steps and expands', total_expanded, 'cells.')

maze_sol_bfs = draw_path(maze_map, total_path, start)
write_sol_to_file(sname_bfs_4, maze_sol_bfs)
# Out:
# ((1, 1), 19.5)
# ((1, 8), 21.0)
# ((2, 3), 16.5)
# ((3, 6), 16.5)
# ((3, 8), 22.0)
# ((4, 2), 18.0)
# ((5, 1), 19.0)
# ((5, 4), 15.0)
# ((5, 7), 19.5)
# ((6, 8), 20.0)
# ((7, 1), 20.0)
# ((7, 6), 18.5)
# (4, 4) --->> (5, 4)
# ((1, 1), 19.0)
# ((1, 8), 20.0)
# ((2, 3), 16.0)
# ((3, 6), 16.0)
# ((3, 8), 21.0)
# ((4, 2), 17.0)
# ((5, 1), 18.0)
# ((5, 7), 18.0)
# ((6, 8), 19.0)
# ((7, 1), 19.0)
# ((7, 6), 17.5)
# (5, 4) --->> (2, 3)
# ((1, 1), 17.0)
# ((1, 8), 19.0)
# ((3, 6), 14.5)
# ((3, 8), 20.0)
# ((4, 2), 16.0)
# ((5, 1), 17.0)
# ((5, 7), 17.0)
# ((6, 8), 18.0)
# ((7, 1), 18.5)
# ((7, 6), 17.0)
# (2, 3) --->> (3, 6)
# ((1, 1), 15.5)
# ((1, 8), 17.5)
# ((3, 8), 18.5)
# ((4, 2), 14.5)
# ((5, 1), 15.5)
# ((5, 7), 15.5)
# ((6, 8), 16.5)
# ((7, 1), 17.0)
# ((7, 6), 15.5)
# (3, 6) --->> (4, 2)
# ((1, 1), 14.5)
# ((1, 8), 16.5)
# ((3, 8), 17.5)
# ((5, 1), 14.5)
# ((5, 7), 14.5)
# ((6, 8), 15.5)
# ((7, 1), 16.0)
# ((7, 6), 14.5)
# (4, 2) --->> (1, 1)
# ((1, 8), 14.5)
# ((3, 8), 15.5)
# ((5, 1), 11.5)
# ((5, 7), 12.5)
# ((6, 8), 13.5)
# ((7, 1), 14.0)
# ((7, 6), 12.5)
# (1, 1) --->> (5, 1)
# ((1, 8), 13.5)
# ((3, 8), 14.5)
# ((5, 7), 11.5)
# ((6, 8), 12.5)
# ((7, 1), 11.0)
# ((7, 6), 12.5)
# (5, 1) --->> (7, 1)
# ((1, 8), 11.0)
# ((3, 8), 12.0)
# ((5, 7), 9.0)
# ((6, 8), 10.0)
# ((7, 6), 8.5)
# (7, 1) --->> (7, 6)
# ((1, 8), 9.5)
# ((3, 8), 10.5)
# ((5, 7), 6.5)
# ((6, 8), 8.5)
# (7, 6) --->> (5, 7)
# ((1, 8), 8.5)
# ((3, 8), 9.5)
# ((6, 8), 7.0)
# (5, 7) --->> (6, 8)
# ((1, 8), 7.0)
# ((3, 8), 7.0)
# (6, 8) --->> (1, 8)
# ja
# (1, 8) --->> (3, 8)
# bfs takes 0.02129000000000003 seconds, costs 43 steps and expands 565 cells.

# %%
maze_map, start, goal_dict, index_dict = parse_file(fname)

total_path = ''
total_expanded = 0


# print(goal_dict)
# print(index_dict)
timer_s = time.clock()

dist_dict = {}
for goal_i, goal_j in combinations(index_dict.keys(), r = 2):
    path, expanded = find_path_astar(maze_map, goal_i, goal_j)
    total_expanded += expanded
    dist = len(path)
    dist_dict[(goal_i, goal_j)] = dist
    dist_dict[(goal_j, goal_i)] = dist

goal_arr = list(index_dict.keys())
print(goal_arr)

curr_node = start
next_node = curr_node

while goal_arr:
    length = len(goal_arr)
    
    if length == 1:
        print('DONE')
        break
        
    t = Tree(length)
    for i in range(length - 1):
        for j in range(i + 1, length):
            goal_i = goal_arr[i]
            goal_j = goal_arr[j]
            dist = dist_dict[(goal_i, goal_j)]
            t.addEdge(i, j, dist)
    mst = t.KruskalMST()
    
    curr_index = goal_arr.index(curr_node)
    edges = []
    for edge in mst:
        if edge[0] == curr_index or edge[1] == curr_index:
            edges.append(edge)
    
    sorted(edges, key=lambda edge: edge[2])
    if edges[0][1] == curr_index:
        next_index = edges[0][0]
    else: 
        next_index = edges[0][1]
    next_node = goal_arr[next_index]
    
    print(curr_node, '--->>', next_node)
    path, expanded = find_path_astar(maze_map, curr_node, next_node)
    
    total_path += path
    
    goal_arr.remove(curr_node)
    curr_node = next_node
    curr_index = index_dict[curr_node]

timer_t = time.clock()
print('bfs takes', timer_t - timer_s, 
      'seconds, costs', len(total_path), 
      'steps and expands', total_expanded, 'cells.')

maze_sol_bfs = draw_path(maze_map, total_path, start)
write_sol_to_file(sname_bfs_5, maze_sol_bfs)
# Out:
# [(1, 1), (1, 8), (2, 3), (3, 6), (3, 8), (4, 2), (4, 4), (5, 4), (5, 7), (6, 8), (7, 1)]
# (4, 4) --->> (5, 4)
# (5, 4) --->> (4, 2)
# (4, 2) --->> (1, 1)
# (1, 1) --->> (2, 3)
# (2, 3) --->> (3, 6)
# (3, 6) --->> (5, 7)
# (5, 7) --->> (6, 8)
# (6, 8) --->> (3, 8)
# (3, 8) --->> (1, 8)
# (1, 8) --->> (7, 1)
# DONE
# bfs takes 0.008216999999999919 seconds, costs 38 steps and expands 1170 cells.
